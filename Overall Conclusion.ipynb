# %% [markdown]
# **Introduction**
# Our metrics were walkability, major crime rates, and the overall environmental population. We chose these metrics as a whole because they are all decently connected to each other in terms of their relation to Pittsburgh. Pollution is especially important for your personal health along with your safety and overall experience getting around the city (especially on foot).

# %% [markdown]
# **Overall Conclusions**
#
# Overall the best neighbourhood would actually be Oakland, in terms of walkability, and pollution it ranks amazingly. Additionally its crime rate is relatively low in regards to its population which would make it the most ideal neighbourhood in regards to all the metrics we sorted.
